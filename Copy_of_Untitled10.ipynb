#   inflating: impressionist_dataset/training/training/Degas/213647.jpg
#   inflating: impressionist_dataset/training/training/Degas/213649.jpg
#   inflating: impressionist_dataset/training/training/Degas/213651.jpg
#   inflating: impressionist_dataset/training/training/Degas/213652.jpg
#   inflating: impressionist_dataset/training/training/Degas/213654.jpg
#   inflating: impressionist_dataset/training/training/Degas/213655.jpg
#   inflating: impressionist_dataset/training/training/Degas/213657.jpg
#   inflating: impressionist_dataset/training/training/Degas/213658.jpg
#   inflating: impressionist_dataset/training/training/Degas/213659.jpg
# ...
#   inflating: impressionist_dataset/validation/validation/Renoir/219514.jpg
#   inflating: impressionist_dataset/validation/validation/Renoir/219551.jpg
#   inflating: impressionist_dataset/validation/validation/Renoir/219553.jpg
#   inflating: impressionist_dataset/validation/validation/Renoir/219558.jpg
#   inflating: impressionist_dataset/validation/validation/Renoir/219568.jpg
#   inflating: impressionist_dataset/validation/validation/Renoir/219587.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265650.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265654.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265657.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265658.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265673.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265675.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265688.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265696.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265701.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265709.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265711.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265724.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265725.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265733.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265734.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265747.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265752.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265764.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265797.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265798.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265805.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265806.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265809.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265820.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265834.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265843.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265853.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265854.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265865.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265870.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265875.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265882.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265888.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265898.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265901.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265917.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265936.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265937.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265964.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265965.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265968.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265971.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265990.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/265998.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266004.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266025.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266046.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266049.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266060.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266063.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266094.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266098.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266106.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266112.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266122.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266125.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266138.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266139.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266145.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266148.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266158.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266159.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266172.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266174.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266178.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266195.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266203.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266204.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266219.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266230.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266235.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266241.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266245.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266258.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266259.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266263.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266268.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266279.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266284.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266294.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266298.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266305.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266306.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266309.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266312.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266319.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266355.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266359.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266368.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266375.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266385.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266391.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266407.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266409.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266422.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266424.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/266429.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/9223372032559840631.jpg
#   inflating: impressionist_dataset/validation/validation/Sargent/9223372032559840707.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/205655.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/205684.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/205688.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/205754.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/205762.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/205820.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/205846.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/205858.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/205881.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/205893.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/205918.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/205950.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/205968.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/205994.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206027.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206077.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206146.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206151.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206175.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206177.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206204.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206253.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206260.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206270.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206282.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206287.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206289.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206322.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206326.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206354.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206386.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206398.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206449.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206451.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206478.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206516.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206523.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206539.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206554.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206555.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206556.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206580.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206589.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206611.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206619.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206650.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206665.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206699.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206719.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206747.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206748.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206760.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206765.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206772.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206807.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206824.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206840.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206842.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206844.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206861.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206888.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206900.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206927.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206930.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206935.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206940.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206964.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206969.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206980.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/206992.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207003.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207013.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207014.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207037.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207047.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207110.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207112.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207124.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207187.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207230.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207263.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207285.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207292.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207302.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207324.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207367.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207391.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207393.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207412.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207423.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207430.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207439.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207442.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207443.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207446.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207471.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207486.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/207542.jpg
#   inflating: impressionist_dataset/validation/validation/VanGogh/9223372032559834926.jpg

# %%
import matplotlib.pyplot as plt
from PIL import Image
import seaborn as sns
import pandas as pd

# %%
  # Directory where the dataset is extracted

# Path to the dataset directory
# Path to the dataset directory
dataset_dir = 'impressionist_dataset'
training_dir = os.path.join(dataset_dir, 'training', 'training')  # Corrected path

# List of painters (class names)
painters = os.listdir(training_dir)
num_painters = len(painters)

print(f"Number of painters: {num_painters}")
print("Painter names:", painters)

# Distribution of images by painter
painter_counts = [len(os.listdir(os.path.join(training_dir, painter))) for painter in painters]

plt.figure(figsize=(10, 6))
sns.barplot(x=painter_counts, y=painters)
plt.xlabel("Number of Images")
plt.ylabel("Painter")
plt.title("Distribution of Images by Painter")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Sample images from each painter
num_samples = 3

plt.figure(figsize=(15, 10))

for painter in painters:
    painter_dir = os.path.join(training_dir, painter)
    sample_images = os.listdir(painter_dir)[:num_samples]

    for idx, image_name in enumerate(sample_images):
        image_path = os.path.join(painter_dir, image_name)
        if os.path.isfile(image_path):  # Check if the path is a file
            image = Image.open(image_path)
            plt.subplot(num_painters, num_samples, idx + 1 + painters.index(painter) * num_samples)
            plt.imshow(image)
            plt.title(painter)
            plt.axis('off')

plt.tight_layout()
plt.show()

# Image dimensions
image_dimensions = []

for painter in painters:
    painter_dir = os.path.join(training_dir, painter)
    image_names = os.listdir(painter_dir)
    for image_name in image_names:
        image_path = os.path.join(painter_dir, image_name)
        if os.path.isfile(image_path):  # Check if the path is a file
            image = Image.open(image_path)
            width, height = image.size
            image_dimensions.append((width, height))

df_dimensions = pd.DataFrame(image_dimensions, columns=['Width', 'Height'])

plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_dimensions, x='Width', y='Height')
plt.xlabel("Image Width")
plt.ylabel("Image Height")
plt.title("Distribution of Image Dimensions")
plt.show()
# Out:
# Number of painters: 10
# Painter names: ['Gauguin', 'Matisse', 'VanGogh', 'Cezanne', 'Pissarro', 'Renoir', 'Degas', 'Sargent', 'Monet', 'Hassam']

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Set random seed for reproducibility
seed = 42
np.random.seed(seed)
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Directories
train_directory = '/content/impressionist_dataset/training'
valid_directory = '/content/impressionist_dataset/validation'

# Hyperparameters
bs = 64
num_epochs = 2
num_classes = 10

# Image Transforms
image_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# Load data from folders
train_dataset = datasets.ImageFolder(root=train_directory, transform=image_transforms['train'])
valid_dataset = datasets.ImageFolder(root=valid_directory, transform=image_transforms['valid'])

# Split train_dataset into train and test sets
train_size = int(0.8 * len(train_dataset))
test_size = len(train_dataset) - train_size
train_dataset, test_dataset = random_split(train_dataset, [train_size, test_size])

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=bs, shuffle=True, pin_memory=True, drop_last=True)
valid_loader = DataLoader(valid_dataset, batch_size=bs, shuffle=True, pin_memory=True, drop_last=True)

# Class names
class_names = train_dataset.dataset.classes


# Model
model = models.resnet18(pretrained=True)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, num_classes)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Loss function
criterion = nn.CrossEntropyLoss()

# Optimizer
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Lists to store training and validation losses
train_losses = []
valid_losses = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    # Calculate and store average training loss for this epoch
    train_loss = running_loss / len(train_loader)
    train_losses.append(train_loss)

    # Validation loss
    model.eval()
    running_loss = 0.0
    with torch.no_grad():
        for images, labels in valid_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_loss += loss.item()

    # Calculate and store average validation loss for this epoch
    valid_loss = running_loss / len(valid_loader)
    valid_losses.append(valid_loss)

    print(f"Epoch [{epoch+1}/{num_epochs}] - Train Loss: {train_loss:.4f} - Valid Loss: {valid_loss:.4f}")

# Plot training and validation losses
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.plot(valid_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Losses')
plt.legend()
plt.show()

# ... (Code for plotting randomly selected test images and calculating accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 118MB/s]
# Epoch [1/2] - Train Loss: 0.1359 - Valid Loss: 0.0000
# Epoch [2/2] - Train Loss: 0.0000 - Valid Loss: 0.0000

# %%
# ... (Previous code)

# Display randomly selected test images and their predictions
model.eval()
num_samples = 5
random_indices = np.random.randint(0, len(test_dataset), num_samples)
plt.figure(figsize=(15, 7))
for i, idx in enumerate(random_indices):
    image, label = test_dataset[idx]
    image = image.unsqueeze(0).to(device)

    with torch.no_grad():
        output = model(image)
        predicted_label = output.argmax().item()

    # Get the class names and class-to-index mapping
    original_classes = test_dataset.dataset.classes
    class_to_idx = test_dataset.dataset.class_to_idx

    # Get the actual class names from the class-to-index mapping
    true_class = original_classes[label]
    predicted_class = original_classes[predicted_label]

    plt.subplot(1, num_samples, i + 1)
    plt.imshow(image.cpu().squeeze().permute(1, 2, 0))
    plt.title(f'True: {true_class}\nPredicted: {predicted_class}')
    plt.axis('off')

plt.show()

# ... (Rest of your code)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
torch.save(model.state_dict(), 'model_checkpoint.pth')

# %%
# Display randomly selected validation images and their predictions
model.eval()
num_samples = 5
random_indices = np.random.randint(0, len(valid_dataset), num_samples)  # Use valid_dataset here
plt.figure(figsize=(15, 7))
for i, idx in enumerate(random_indices):
    image, label = valid_dataset[idx]  # Use valid_dataset here
    image = image.unsqueeze(0).to(device)

    with torch.no_grad():
        output = model(image)
        predicted_label = output.argmax().item()

    # Get the class-to-index mapping
    class_to_idx = valid_dataset.class_to_idx

    # Get the actual class name from the class-to-index mapping
    true_class_idx = label  # label is already the class index
    predicted_class_idx = predicted_label
    true_class = list(class_to_idx.keys())[list(class_to_idx.values()).index(true_class_idx)]
    predicted_class = list(class_to_idx.keys())[list(class_to_idx.values()).index(predicted_class_idx)]

    plt.subplot(1, num_samples, i + 1)
    plt.imshow(image.cpu().squeeze().permute(1, 2, 0))
    plt.title(f'True: {true_class}\nPredicted: {predicted_class}')
    plt.axis('off')

plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import torchvision
from torchvision import transforms

# Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the dataset
train_dataset = torchvision.datasets.ImageFolder(root='/content/impressionist_dataset/training', transform=transform)

# Create a DataLoader for the dataset
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=bs, shuffle=True)

# Access class names from the dataset
class_names = train_dataset.classes

# Now you can use class_names for further processing

# %%
# ... (previous code)

# Make predictions using the model
model.eval()  # Set the model to evaluation mode
with torch.no_grad():
    output = model(image)

print("Model output:", output)  # Print the output tensor for debugging

# Load class names
class_names = ["Cezanne", "Degas", "Gauguin", "Hassam", "Matisse", "Monet", "Pissarro", "Renoir", "Sargent", "VanGogh"]

# Check model output dimensions
print("Number of predicted classes:", output.shape[1])
print("Number of class names:", len(class_names))

# Get predicted class index
predicted_class_idx = torch.argmax(output).item()

# Check if predicted_class_idx is within valid range
if predicted_class_idx < len(class_names):
    predicted_class = class_names[predicted_class_idx]
    print("Predicted class:", predicted_class)
else:
    print("Predicted class index out of range.")
# Out:
# Model output: tensor([[ 2.6483e+00,  2.5298e+00, -2.9239e+00, -5.5763e-01, -5.4350e-01,
#           2.8790e-01,  6.1463e-03, -1.1529e-01,  2.1714e-01,  1.6080e+00,
#          -3.0118e+00, -1.1023e+00, -1.9777e+00, -2.7034e+00,  6.3241e-01,
#          -2.4899e+00, -3.3360e+00,  4.7307e-01, -3.7628e-01, -1.9811e+00,
